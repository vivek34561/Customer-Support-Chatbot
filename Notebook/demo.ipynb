# %%
import pandas as pd

df = pd.read_csv("hf://datasets/bitext/Bitext-customer-support-llm-chatbot-training-dataset/Bitext_Sample_Customer_Support_Training_Dataset_27K_responses-v11.csv")
df
# Out:
#        flags                                        instruction category  \
# 0          B   question about cancelling order {{Order Number}}    ORDER
# 1        BQZ  i have a question about cancelling oorder {{Or...    ORDER
# 2       BLQZ    i need help cancelling puchase {{Order Number}}    ORDER
# 3         BL         I need to cancel purchase {{Order Number}}    ORDER
# 4      BCELN  I cannot afford this order, cancel purchase {{...    ORDER
# ...      ...                                                ...      ...
# 26867     BL  I am waiting for a rebate of {{Refund Amount}}...   REFUND
# 26868    BIL  how to see if there is anything wrong with my ...   REFUND
# 26869   BLQZ  I'm waiting for a reimbjrsement of {{Currency ...   REFUND
# 26870     BL  I don't know what to do to see my reimbursemen...   REFUND
# 26871     BL  I need to know if there is anything new on the...   REFUND
#
#              intent                                           response
# 0      cancel_order  I've understood you have a question regarding ...
# 1      cancel_order  I've been informed that you have a question ab...
# 2      cancel_order  I can sense that you're seeking assistance wit...
# 3      cancel_order  I understood that you need assistance with can...
# 4      cancel_order  I'm sensitive to the fact that you're facing f...
# ...             ...                                                ...
# 26867  track_refund  Thank you for sharing your situation regarding...
# 26868  track_refund  Ensuring the accuracy of your restitution is o...
# 26869  track_refund  Firstly, I genuinely understand the importance...
# 26870  track_refund  I've understood you're unsure about how to che...
# 26871  track_refund  It's completely understandable that you want t...
#
# [26872 rows x 5 columns]

# %%
df.shape
# Out:
# (26872, 5)

# %%
df.head(2)
# Out:
#   flags                                        instruction category  \
# 0     B   question about cancelling order {{Order Number}}    ORDER
# 1   BQZ  i have a question about cancelling oorder {{Or...    ORDER
#
#          intent                                           response
# 0  cancel_order  I've understood you have a question regarding ...
# 1  cancel_order  I've been informed that you have a question ab...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 26872 entries, 0 to 26871
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   flags        26872 non-null  str
#  1   instruction  26872 non-null  str
#  2   category     26872 non-null  str
#  3   intent       26872 non-null  str
#  4   response     26872 non-null  str
# dtypes: str(5)
# memory usage: 1.0 MB

# %%
df.sample(10)
# Out:
#           flags                                        instruction  category  \
# 20099      BLQZ         I don't know how I can reset my accont pwd   ACCOUNT
# 19325       BLM                   assistance to shop some products     ORDER
# 15784         B  I don't know what to do to get the invoice #12588   INVOICE
# 5926         BL  help me see in what cases can I ask to be reim...    REFUND
# 7513         BL                    I want to make a customer claim  FEEDBACK
# 13880        BL  I call to check when my product is going to ar...  DELIVERY
# 4861   BCILMPQZ  I'd like to find my bills from {{Person Name}}...   INVOICE
# 12400        BL             assistance seeing the shipping methods  DELIVERY
# 1812       BILQ            how do i edit purchase {{Order Number}}     ORDER
# 4762        BKM             checking invoices from {{Person Name}}   INVOICE
#
#                     intent                                           response
# 20099     recover_password  Oh no, it can be quite frustrating when you're...
# 19325          place_order  Thank you for seeking assistance with shopping...
# 15784          get_invoice  I completely understand your uncertainty about...
# 5926   check_refund_policy  I'll take care of it! I'm here to assist you i...
# 7513             complaint  I understand your need to make a customer clai...
# 13880      delivery_period  Thank you for your enthusiasm in seeking updat...
# 4861         check_invoice  I understood that you would like to find your ...
# 12400     delivery_options  I'm happy to help! I'm here to provide you wit...
# 1812          change_order  We understand that you would like to edit your...
# 4762         check_invoice  Positively! I understand your need to check th...

# %%
df['category'].value_counts()
# Out:
# category
# ACCOUNT         5986
# ORDER           3988
# REFUND          2992
# INVOICE         1999
# CONTACT         1999
# PAYMENT         1998
# FEEDBACK        1997
# DELIVERY        1994
# SHIPPING        1970
# SUBSCRIPTION     999
# CANCEL           950
# Name: count, dtype: int64

# %%
df[df['category'] == 'ACCOUNT'].head()
# Out:
#      flags                                        instruction category  \
# 9913  BKLZ               new {{Account Type}} acount for wife  ACCOUNT
# 9914  BILW  how to open a different fucking {{Account Type...  ACCOUNT
# 9915   BKL                       new {{Account Type}} account  ACCOUNT
# 9916    BQ  i have a problem with creating a freemium account  ACCOUNT
# 9917  BKLZ                  opdn {{Account Category}} account  ACCOUNT
#
#               intent                                           response
# 9913  create_account  It's fantastic to hear that you would like to ...
# 9914  create_account  I appreciate your interest in opening a new {{...
# 9915  create_account  We appreciate your interest in creating a new ...
# 9916  create_account  I'm sorry to hear that you're experiencing dif...
# 9917  create_account  Wow! I'm thrilled to be a part of your journey...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 26872 entries, 0 to 26871
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   flags        26872 non-null  str
#  1   instruction  26872 non-null  str
#  2   category     26872 non-null  str
#  3   intent       26872 non-null  str
#  4   response     26872 non-null  str
# dtypes: str(5)
# memory usage: 1.0 MB
